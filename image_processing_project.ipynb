# %%
import sys
print(sys.version)
# Out:
# 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image and convert to grayscale
def load_image(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (128, 128))  # Resize
    return img

# Apply a custom filter (Edge Detection)
def apply_filter(image_path):
    img = load_image(image_path)

    # Apply a Sobel filter for edge detection
    sobel_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)  # X direction
    sobel_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)  # Y direction
    filtered_img = cv2.magnitude(sobel_x, sobel_y)  # Combine gradients

    # Show original and filtered images
    plt.figure(figsize=(8, 4))
    
    plt.subplot(1, 2, 1)
    plt.imshow(img, cmap='gray')
    plt.title("Original Image")
    
    plt.subplot(1, 2, 2)
    plt.imshow(filtered_img, cmap='gray')
    plt.title("Filtered Image")
    
    plt.show()

# Example usage (Replace "your_image.jpg" with your actual image)
apply_filter("your_image.jpg")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
print(cv2.__version__)  # This should print the installed OpenCV version
# Out:
# 4.11.0

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached matplotlib-3.10.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 645.5 kB/s eta 0:00:12
#    -- ------------------------------------- 0.5/8.1 MB 645.5 kB/s eta 0:00:12
#    --- ------------------------------------ 0.8/8.1 MB 598.5 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/8.1 MB 598.5 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/8.1 MB 598.5 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/8.1 MB 598.5 kB/s eta 0:00:13
# ...

# %%
import matplotlib.pyplot as plt
print("Matplotlib is installed successfully!")
# Out:
# Matplotlib is installed successfully!

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image (Make sure the image is in the same folder)
image = cv2.imread("test.jpg", cv2.IMREAD_GRAYSCALE)  # Replace with your actual image name

# Check if the image is loaded
if image is None:
    print("Error: Image not found! Make sure it's in the same folder.")
else:
    # Display the image
    plt.imshow(image, cmap="gray")
    plt.title("Loaded Image")
    plt.show()
